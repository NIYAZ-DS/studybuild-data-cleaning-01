# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("First Dataset.xlsx")
df.to_csv("First Dataset.csv", index=False)

# %%
df = pd.read_csv("First Dataset.csv")

# %%
clean_df = df.copy()

# %%
clean_df.shape
# Out:
# (61, 17)

# %%
clean_df.dtypes
# Out:
# customer_id             int64
# first_name             object
# gender                 object
# age                   float64
# city                   object
# province               object
# signup_date            object
# membership_tier        object
# purchase_count          int64
# avg_order_value       float64
# total_spending        float64
# last_purchase_days      int64
# payment_method         object
# device                 object
# discount_used          object
# returned_items          int64
# satisfaction_score      int64
# dtype: object

# %%
clean_df["age"].unique()
# Out:
# array([ 19.,  53.,  31.,  58.,  28.,  43.,  23.,  61., 145.,  41.,  51.,
#         39.,  35.,  47.,  45.,  49.,  30.,  22.,  nan,  50.,  60.,  37.,
#         25.,  34.,  63.,  26.,  42.,  65.,  64.,  54.,  32.,  48.,  59.,
#         62.,  57.])

# %%
clean_df[clean_df["age"] ==145]
# Out:
#    customer_id first_name gender    age   city province signup_date  \
# 9         1010      Arash      F  145.0  Karaj   Alborz  2022-06-25
#
#   membership_tier  purchase_count  avg_order_value  total_spending  \
# 9          Silver              19           381.13         7241.47
#
#    last_purchase_days payment_method   device discount_used  returned_items  \
# 9                 276  Online Wallet  Android            No               7
#
#    satisfaction_score
# 9                   1

# %%
clean_df["age"] = clean_df["age"].astype("Int64")

# %%
clean_df.loc[clean_df["age"] > 100, "age"] = np.nan

# %%
clean_df[clean_df["age"] > 100]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
clean_df["discount_used"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
clean_df["discount_used"] = clean_df["discount_used"].map({
    "Yes": True,
    "No": False
})

# %%
df["signup_date"].head(10)
# Out:
# 0    2025-02-19
# 1    2022-08-19
# 2    2023-06-20
# 3    2021-11-08
# 4    2021-10-21
# 5    2022-01-26
# 6    2025-09-09
# 7    2024-10-03
# 8    2021-05-14
# 9    2022-06-25
# Name: signup_date, dtype: object

# %%
df["signup_date"].str.match(r"^\d{4}-\d{2}-\d{2}$").value_counts()
# Out:
# signup_date
# True    61
# Name: count, dtype: int64

# %%
clean_df["signup_date"] = pd.to_datetime(clean_df["signup_date"])

# %%
clean_df[["age", "discount_used", "signup_date"]].dtypes
# Out:
# age                       Int64
# discount_used              bool
# signup_date      datetime64[ns]
# dtype: object

# %%
clean_df.isna().sum()
# Out:
# customer_id           0
# first_name            0
# gender                0
# age                   2
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        1
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64

# %%
clean_df[clean_df["age"].isna() | clean_df["total_spending"].isna()]
# Out:
#     customer_id first_name gender   age     city province signup_date  \
# 9          1010      Arash      F  <NA>    Karaj   Alborz  2022-06-25
# 19         1020      Kimia      M  <NA>  Isfahan  Isfahan  2024-06-25
# 39         1040       Amir      F    65   Tehran   Tehran  2021-11-02
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 9           Silver              19           381.13         7241.47
# 19          Bronze              16           187.17         2994.72
# 39          Bronze              34            37.66             NaN
#
#     last_purchase_days payment_method   device  discount_used  returned_items  \
# 9                  276  Online Wallet  Android          False               7
# 19                   4           Cash      Web           True               1
# 39                 126           Card  Android           True               3
#
#     satisfaction_score
# 9                    1
# 19                   5
# 39                   2

# %%
clean_df["age"] = clean_df["age"].fillna(
    clean_df["age"].median()
).astype(int)

# %%
check = (clean_df["purchase_count"] * clean_df["avg_order_value"]).round(2) == clean_df["total_spending"].round(2)
clean_df[~check]
# Out:
#     customer_id first_name gender  age     city  province signup_date  \
# 29         1030       Sina      M   60  Mashhad  Khorasan  2025-03-07
# 39         1040       Amir      F   65   Tehran    Tehran  2021-11-02
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 29             VIP              26           156.89         25000.0
# 39          Bronze              34            37.66             NaN
#
#     last_purchase_days payment_method   device  discount_used  returned_items  \
# 29                 340           Cash      Web           True               4
# 39                 126           Card  Android           True               3
#
#     satisfaction_score
# 29                   4
# 39                   2

# %%
calculated = (clean_df["purchase_count"] * clean_df["avg_order_value"]).round(2)

mask = (
    clean_df["total_spending"].isna()
    | (clean_df["total_spending"].round(2) != calculated)
)

clean_df.loc[mask, "total_spending"] = calculated[mask]

# %%
check = (clean_df["purchase_count"] * clean_df["avg_order_value"]).round(2) == clean_df["total_spending"].round(2)
clean_df[~check]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
clean_df.isna().sum()
# Out:
# customer_id           0
# first_name            0
# gender                0
# age                   0
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        0
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64

# %%
clean_df.duplicated().sum()
# Out:
# np.int64(1)

# %%
clean_df[clean_df.duplicated(keep=False)]
# Out:
#     customer_id first_name gender  age    city         province signup_date  \
# 13         1014       Reza      M   35  Tabriz  East Azerbaijan  2022-08-26
# 60         1014       Reza      M   35  Tabriz  East Azerbaijan  2022-08-26
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 13             VIP              31           108.19         3353.89
# 60             VIP              31           108.19         3353.89
#
#     last_purchase_days payment_method   device  discount_used  returned_items  \
# 13                  97           Card  Android          False               5
# 60                  97           Card  Android          False               5
#
#     satisfaction_score
# 13                   4
# 60                   4

# %%
clean_df = clean_df.drop_duplicates()

# %%
clean_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
text_cols = [
    "first_name",
    "gender",
    "city",
    "province",
    "membership_tier",
    "payment_method",
    "device",
    "discount_used"
]

for col in text_cols:
    original = clean_df[col].dropna().astype(str)
    normalized = original.str.strip().str.lower()

    print(
        f"{col}: "
        f"original={original.nunique()}, "
        f"normalized={normalized.nunique()}"
    )
# Out:
# first_name: original=12, normalized=12
# gender: original=2, normalized=2
# city: original=8, normalized=8
# province: original=8, normalized=8
# membership_tier: original=4, normalized=4
# payment_method: original=3, normalized=3
# device: original=3, normalized=3
# discount_used: original=2, normalized=2

# %%
clean_df[[
    "age",
    "purchase_count",
    "avg_order_value",
    "total_spending",
    "last_purchase_days",
    "returned_items",
    "satisfaction_score"
]].describe()
# Out:
#              age  purchase_count  avg_order_value  total_spending  \
# count  60.000000       60.000000        60.000000       60.000000
# mean   43.700000       17.383333       213.156500     3366.428833
# std    13.946994       10.149880       130.509923     3235.132979
# min    19.000000        0.000000        27.630000        0.000000
# 25%    31.750000       10.750000       108.137500     1167.035000
# 50%    45.000000       17.000000       165.435000     2128.690000
# 75%    58.000000       24.500000       324.107500     4213.117500
# max    65.000000       35.000000       449.810000    14354.340000
#
#        last_purchase_days  returned_items  satisfaction_score
# count           60.000000       60.000000           60.000000
# mean           198.600000        4.183333            2.983333
# std             97.843043        2.683861            1.431979
# min              3.000000        0.000000            1.000000
# 25%            134.250000        2.000000            2.000000
# 50%            203.000000        4.000000            3.000000
# 75%            273.750000        7.000000            4.000000
# max            365.000000        8.000000            5.000000

# %%
numeric_cols = [
    "age",
    "purchase_count",
    "avg_order_value",
    "total_spending",
    "last_purchase_days",
    "returned_items",
    "satisfaction_score"
]

for col in numeric_cols:
    Q1 = clean_df[col].quantile(0.25)
    Q3 = clean_df[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    
    outliers = clean_df[(clean_df[col] < lower) | (clean_df[col] > upper)]
    
    print(f"{col}: {len(outliers)} outlier(s)")
# Out:
# age: 0 outlier(s)
# purchase_count: 0 outlier(s)
# avg_order_value: 0 outlier(s)
# total_spending: 5 outlier(s)
# last_purchase_days: 0 outlier(s)
# returned_items: 0 outlier(s)
# satisfaction_score: 0 outlier(s)

# %%
Q1 = clean_df["total_spending"].quantile(0.25)
Q3 = clean_df["total_spending"].quantile(0.75)
IQR = Q3 - Q1

clean_df[clean_df["total_spending"] > Q3 + 1.5 * IQR][
    ["customer_id", "purchase_count", "avg_order_value", "total_spending"]
]
# Out:
#     customer_id  purchase_count  avg_order_value  total_spending
# 8          1009              34           341.63        11615.42
# 11         1012              27           434.50        11731.50
# 43         1044              33           434.98        14354.34
# 56         1057              31           436.54        13532.74
# 58         1059              31           287.05         8898.55

# %%
text_cols = clean_df.select_dtypes(include="object").columns

for col in text_cols:
    count = clean_df[col].astype(str).str.strip().ne(clean_df[col].astype(str)).sum()
    print(f"{col}: {count}")
# Out:
# first_name: 0
# gender: 0
# city: 0
# province: 0
# membership_tier: 0
# payment_method: 0
# device: 0

# %%
from difflib import get_close_matches

cat_cols = [
    "gender",
    "city",
    "province",
    "membership_tier",
    "payment_method",
    "device",
    "discount_used"
]

for col in cat_cols:
    values = clean_df[col].dropna().astype(str).unique()
    found = False

    print(f"\n--- {col} ---")

    for value in values:
        matches = get_close_matches(value, values, n=3, cutoff=0.7)
        matches = [m for m in matches if m != value]

        if matches:
            print(f"{value} -> {matches}")
            found = True

    if not found:
        print("None")
# Out:
# --- gender ---
# None
#
# --- city ---
# None
#
# --- province ---
# None
#
# --- membership_tier ---
# None
#
# --- payment_method ---
# None
#
# --- device ---
# None
#
# --- discount_used ---
# None

# %%
clean_df.loc[
    (clean_df["purchase_count"] > 0) & (clean_df["total_spending"] == 0)
]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
clean_df.loc[
    (clean_df["purchase_count"] == 0) & (clean_df["avg_order_value"] > 0)
]
# Out:
#     customer_id first_name gender  age   city   province signup_date  \
# 23         1024       Sina      F   53  Ahvaz  Khuzestan  2025-01-27
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 23            Gold               0            63.67             0.0
#
#     last_purchase_days payment_method   device  discount_used  returned_items  \
# 23                 298  Online Wallet  Android          False               2
#
#     satisfaction_score
# 23                   1

# %%
clean_df.loc[
    clean_df["returned_items"] > clean_df["purchase_count"]
]
# Out:
#     customer_id first_name gender  age    city         province signup_date  \
# 7          1008       Reza      F   23   Rasht            Gilan  2024-10-03
# 14         1015      Kimia      F   47   Ahvaz        Khuzestan  2021-07-24
# 23         1024       Sina      F   53   Ahvaz        Khuzestan  2025-01-27
# 28         1029        Ali      F   34  Tabriz  East Azerbaijan  2023-07-03
# 36         1037      Zahra      M   42   Ahvaz        Khuzestan  2024-01-12
# 55         1056      Kimia      M   61  Tabriz  East Azerbaijan  2025-01-25
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 7              VIP               3           389.58         1168.74
# 14            Gold               3           307.91          923.73
# 23            Gold               0            63.67            0.00
# 28            Gold               2           323.32          646.64
# 36            Gold               1           387.68          387.68
# 55          Silver               1           449.81          449.81
#
#     last_purchase_days payment_method   device  discount_used  returned_items  \
# 7                  195  Online Wallet   iPhone          False               8
# 14                  55           Card  Android           True               8
# 23                 298  Online Wallet  Android          False               2
# 28                 319           Cash      Web           True               4
# 36                 199           Cash      Web           True               7
# 55                 240  Online Wallet      Web          False               4
#
#     satisfaction_score
# 7                    1
# 14                   4
# 23                   1
# 28                   5
# 36                   2
# 55                   2

# %%
clean_df.loc[
    (clean_df["purchase_count"] == 0) &
    (clean_df["returned_items"] == 0) &
    (clean_df["satisfaction_score"].notna())
]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
clean_df.loc[
    (clean_df["discount_used"] == "Yes") & (clean_df["purchase_count"] == 0)
]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
clean_df.loc[
    (clean_df["discount_used"] == "Yes") & (clean_df["avg_order_value"] == 0)
]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
clean_df.loc[
    (clean_df["discount_used"] == "Yes") & (clean_df["total_spending"] == 0)
]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
clean_df.loc[
    (clean_df["purchase_count"] == 0) &
    (clean_df["returned_items"] == 0) &
    (clean_df["last_purchase_days"].notna())
]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
cols = [
    "age",
    "purchase_count",
    "avg_order_value",
    "total_spending",
    "last_purchase_days",
    "returned_items"
]

for col in cols:
    print(f"{col}: {(clean_df[col] < 0).sum()}")
# Out:
# age: 0
# purchase_count: 0
# avg_order_value: 0
# total_spending: 0
# last_purchase_days: 0
# returned_items: 0

# %%
clean_df["signup_date"].max()
# Out:
# Timestamp('2025-09-09 00:00:00')

# %%
for gender, group in clean_df.groupby("gender"):
    print(f"\n{gender}:")
    print(group["first_name"].to_list())
# Out:
# F:
# ['Reza', 'Parsa', 'Sina', 'Amir', 'Reza', 'Reza', 'Arash', 'Neda', 'Arash', 'Neda', 'Kimia', 'Neda', 'Parsa', 'Ali', 'Amir', 'Ali', 'Sina', 'Neda', 'Kimia', 'Mina', 'Ali', 'Neda', 'Neda', 'Sina', 'Amir', 'Sina', 'Maryam', 'Sina', 'Ali', 'Reza', 'Parsa', 'Sara', 'Reza', 'Amir', 'Ali']
#
# M:
# ['Sina', 'Kimia', 'Kimia', 'Reza', 'Neda', 'Kimia', 'Reza', 'Amir', 'Sina', 'Zahra', 'Maryam', 'Arash', 'Zahra', 'Amir', 'Parsa', 'Neda', 'Kimia', 'Mina', 'Maryam', 'Arash', 'Sina', 'Mina', 'Kimia', 'Maryam', 'Ali']

# %%
gender_ref = pd.read_csv("persian-gender-by-name.csv")

# %%
gender_ref.columns
# Out:
# Index(['name', 'gender', 'english_name'], dtype='object')

# %%
clean_df["name_clean"] = (
    clean_df["first_name"]
    .str.strip()
    .str.lower()
)

gender_ref["name_clean"] = (
    gender_ref["english_name"]
    .str.strip()
    .str.lower()
)

# %%
check = clean_df.merge(
    gender_ref[["name_clean", "gender"]],
    on="name_clean",
    how="left"
)

# %%
check.columns
# Out:
# Index(['customer_id', 'first_name', 'gender_x', 'age', 'city', 'province',
#        'signup_date', 'membership_tier', 'purchase_count', 'avg_order_value',
#        'total_spending', 'last_purchase_days', 'payment_method', 'device',
#        'discount_used', 'returned_items', 'satisfaction_score', 'name_clean',
#        'gender_y'],
#       dtype='object')

# %%
check.loc[
    check["gender_y"].notna() &
    (check["gender_x"] != check["gender_y"]),
    ["customer_id", "first_name", "gender_x", "gender_y"]
]
# Out:
#      customer_id first_name gender_x gender_y
# 0           1001       Reza        F        m
# 1           1001       Reza        F        m
# 2           1002       Sina        M        m
# 3           1003      Parsa        F        m
# 4           1004       Sina        F        m
# ..           ...        ...      ...      ...
# 97          1059        Ali        F        m
# 98          1059        Ali        F        m
# 99          1060        Ali        M        m
# 100         1060        Ali        M        m
# 101         1060        Ali        M        m
#
# [95 rows x 4 columns]

# %%
check["gender_y"] = check["gender_y"].str.upper()

# %%
mask = (
    check["gender_y"].notna() &
    (check["gender_x"] != check["gender_y"])
)

# %%
mask = (
    check["gender_y"].notna() &
    (check["gender_x"] != check["gender_y"])
)

check.loc[mask, "gender_x"] = check.loc[mask, "gender_y"]

# %%
gender_map = (
    gender_ref
    .dropna(subset=["name_clean", "gender"])
    .drop_duplicates("name_clean")
    .set_index("name_clean")["gender"]
)

# %%
clean_df["gender_ref"] = clean_df["name_clean"].map(gender_map)

# %%
mask = (
    clean_df["gender_ref"].notna() &
    (clean_df["gender"] != clean_df["gender_ref"])
)

# %%
clean_df.loc[mask, "gender"] = clean_df.loc[mask, "gender_ref"]

# %%
clean_df.drop(columns=["name_clean", "gender_ref"], inplace=True)

# %%
print(check["gender_x"].unique())
print(check["gender_y"].unique())
# Out:
# ['F' 'M']
# ['M' nan 'F']

# %%
check.loc[
    check["first_name"].str.lower().str.contains("kimia", na=False),
    ["first_name", "name_clean", "gender_x", "gender_y"]
]
# Out:
#    first_name name_clean gender_x gender_y
# 5       Kimia      kimia        M      NaN
# 11      Kimia      kimia        M      NaN
# 24      Kimia      kimia        F      NaN
# 33      Kimia      kimia        M      NaN
# 44      Kimia      kimia        F      NaN
# 70      Kimia      kimia        M      NaN
# 93      Kimia      kimia        M      NaN

# %%
gender_ref[
    gender_ref["english_name"]
    .str.lower()
    .str.contains("kimia", na=False)
][["english_name", "gender"]]
# Out:
# Empty DataFrame
# Columns: [english_name, gender]
# Index: []

# %%
clean_df.loc[
    clean_df["first_name"].str.strip().str.lower() == "kimia",
    "gender"
] = "f"

# %%
clean_df.loc[
    clean_df["first_name"].str.strip().str.lower() == "kimia",
    ["first_name", "gender"]
]
# Out:
#    first_name gender
# 4       Kimia      f
# 8       Kimia      f
# 14      Kimia      f
# 19      Kimia      f
# 26      Kimia      f
# 42      Kimia      f
# 55      Kimia      f

# %%
df.shape
# Out:
# (61, 17)

# %%
clean_df.info()
clean_df.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 0 to 59
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         60 non-null     int64
#  1   first_name          60 non-null     object
#  2   gender              60 non-null     object
#  3   age                 60 non-null     int64
#  4   city                60 non-null     object
#  5   province            60 non-null     object
#  6   signup_date         60 non-null     datetime64[ns]
#  7   membership_tier     60 non-null     object
#  8   purchase_count      60 non-null     int64
#  9   avg_order_value     60 non-null     float64
#  10  total_spending      60 non-null     float64
#  11  last_purchase_days  60 non-null     int64
#  12  payment_method      60 non-null     object
#  13  device              60 non-null     object
#  14  discount_used       60 non-null     bool
#  15  returned_items      60 non-null     int64
#  16  satisfaction_score  60 non-null     int64
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(6), object(7)
# memory usage: 8.0+ KB
#                    count                 mean                  min  \
# customer_id         60.0               1030.5               1001.0
# age                 60.0                 43.7                 19.0
# signup_date           60  2023-02-03 14:00:00  2021-02-23 00:00:00
# purchase_count      60.0            17.383333                  0.0
# avg_order_value     60.0             213.1565                27.63
# total_spending      60.0          3366.428833                  0.0
# last_purchase_days  60.0                198.6                  3.0
# returned_items      60.0             4.183333                  0.0
# satisfaction_score  60.0             2.983333                  1.0
#
#                                     25%                  50%  \
# customer_id                     1015.75               1030.5
# age                               31.75                 45.0
# signup_date         2021-12-06 12:00:00  2022-08-15 00:00:00
# purchase_count                    10.75                 17.0
# avg_order_value                108.1375              165.435
# total_spending                 1167.035              2128.69
# last_purchase_days               134.25                203.0
# returned_items                      2.0                  4.0
# satisfaction_score                  2.0                  3.0
#
#                                     75%                  max          std
# customer_id                     1045.25               1060.0    17.464249
# age                                58.0                 65.0    13.946994
# signup_date         2024-06-14 12:00:00  2025-09-09 00:00:00          NaN
# purchase_count                     24.5                 35.0     10.14988
# avg_order_value                324.1075               449.81   130.509923
# total_spending                4213.1175             14354.34  3235.132979
# last_purchase_days               273.75                365.0    97.843043
# returned_items                      7.0                  8.0     2.683861
# satisfaction_score                  4.0                  5.0     1.431979

# %%
clean_df.to_excel("cleaned_dataset.xlsx", index=False)
