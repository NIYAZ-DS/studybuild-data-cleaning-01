# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("D:\projects\project-01-data-cleaning\data\cleaned_dataset.xlsx")

# %%
# age distribution
plt.figure(figsize=(8,5))
plt.hist(df["age"],bins=10)
plt.title("age distribution")
plt.xlabel("age")
plt.ylabel("number of customers")
plt.show()

# %%
# membership tier distribution
df["membership_tier"].value_counts().plot(kind="bar")

plt.title("Membership Tier Distribution")
plt.xlabel("Membership Tier")
plt.ylabel("Count")
plt.show()

# %%
# payment methods

df["payment_method"].value_counts().plot(kind="bar")

plt.title("Payment Methods")
plt.xlabel("Payment Method")
plt.ylabel("Count")
plt.show()

# %%
# device usage

df["device"].value_counts().plot(kind="bar")

plt.title("Device Usage")
plt.xlabel("Device")
plt.ylabel("Count")
plt.show()

# %%
# Average Spending by Membership

df.groupby("membership_tier")["total_spending"].mean().plot(kind="bar")

plt.title("Average Spending by Membership")
plt.xlabel("Membership Tier")
plt.ylabel("Average Spending")
plt.show()

# %%
df.head()
# Out:
#    customer_id first_name gender  age     city  province signup_date  \
# 0         1001       Reza      M   19    Karaj    Alborz  2025-02-19
# 1         1002       Sina      M   53   Tehran    Tehran  2022-08-19
# 2         1003      Parsa      M   31   Shiraz      Fars  2023-06-20
# 3         1004       Sina      M   58  Mashhad  Khorasan  2021-11-08
# 4         1005      Kimia      F   28  Isfahan   Isfahan  2021-10-21
#
#   membership_tier  purchase_count  avg_order_value  total_spending  \
# 0             VIP              17           121.53         2066.01
# 1            Gold              12           326.47         3917.64
# 2            Gold              21            59.46         1248.66
# 3            Gold              23           266.15         6121.45
# 4          Silver              23           169.54         3899.42
#
#    last_purchase_days payment_method   device discount_used  returned_items  \
# ...
